# %% [markdown]
# # College Major Salary Analysis

# %%
import pandas as pd

# %%
df=pd.read_csv("salaries_by_college_major.csv")

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group
# 0  Business
# 1      STEM
# 2  Business
# 3      HASS
# 4  Business

# %%
df.shape
# Out:
# (51, 6)

# %%
df.columns
# Out:
# Index(['Undergraduate Major', 'Starting Median Salary',
#        'Mid-Career Median Salary', 'Mid-Career 10th Percentile Salary',
#        'Mid-Career 90th Percentile Salary', 'Group'],
#       dtype='str')

# %%
df.isna().sum()
# Out:
# Undergraduate Major                  0
# Starting Median Salary               1
# Mid-Career Median Salary             1
# Mid-Career 10th Percentile Salary    1
# Mid-Career 90th Percentile Salary    1
# Group                                1
# dtype: int64

# %%
df=df.dropna()

# %%
df.tail()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 45   Political Science                 40800.0                   78200.0
# 46          Psychology                 35900.0                   60400.0
# 47            Religion                 34100.0                   52000.0
# 48           Sociology                 36500.0                   58200.0
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 45                            41200.0                           168000.0  HASS
# 46                            31600.0                           127000.0  HASS
# 47                            29700.0                            96400.0  HASS
# 48                            30700.0                           118000.0  HASS
# 49                            31000.0                            96400.0  HASS

# %% [markdown]
# ## Finding the highest sarting salary

# %% [markdown]
# ### Technique 1

# %%
df['Starting Median Salary'].max()
# Out:
# np.float64(74300.0)

# %%
df[df['Starting Median Salary']==df['Starting Median Salary'].max()]
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 43  Physician Assistant                 74300.0                   91700.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 43                            66400.0                           124000.0  STEM

# %% [markdown]
# ### Technique 2

# %%
df['Starting Median Salary'].idxmax()
# Out:
# 43

# %%
df['Undergraduate Major'].loc[43]
# Out:
# 'Physician Assistant'

# %%
df.loc[43]
# Out:
# Undergraduate Major                  Physician Assistant
# Starting Median Salary                           74300.0
# Mid-Career Median Salary                         91700.0
# Mid-Career 10th Percentile Salary                66400.0
# Mid-Career 90th Percentile Salary               124000.0
# Group                                               STEM
# Name: 43, dtype: object

# %% [markdown]
# ## Finding lowest starting salary

# %%
df['Starting Median Salary'].min()
# Out:
# np.float64(34000.0)

# %%
df[df['Starting Median Salary']==df['Starting Median Salary'].min()]
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 49             Spanish                 34000.0                   53100.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 49                            31000.0                            96400.0  HASS

# %%
df[df['Starting Median Salary']==df['Starting Median Salary'].min()]['Undergraduate Major']
# Out:
# 49    Spanish
# Name: Undergraduate Major, dtype: str

# %%
df['Starting Median Salary'].idxmin()
# Out:
# 49

# %%
df.loc[49]
# Out:
# Undergraduate Major                  Spanish
# Starting Median Salary               34000.0
# Mid-Career Median Salary             53100.0
# Mid-Career 10th Percentile Salary    31000.0
# Mid-Career 90th Percentile Salary    96400.0
# Group                                   HASS
# Name: 49, dtype: object

# %%
df['Undergraduate Major'].loc[49]
# Out:
# 'Spanish'

# %% [markdown]
# ### Finding college major with lowest mid-career salary

# %%
df['Mid-Career Median Salary'].idxmin()
# Out:
# 18

# %%
df['Undergraduate Major'].loc[18]
# Out:
# 'Education'

# %%
df.loc[18]
# Out:
# Undergraduate Major                  Education
# Starting Median Salary                 34900.0
# Mid-Career Median Salary               52000.0
# Mid-Career 10th Percentile Salary      29300.0
# Mid-Career 90th Percentile Salary     102000.0
# Group                                     HASS
# Name: 18, dtype: object

# %% [markdown]
# ### Finding college majors with highest mid career salary

# %%
df['Mid-Career Median Salary'].max()
# Out:
# np.float64(107000.0)

# %%
df[df['Mid-Career Median Salary']==df['Mid-Career Median Salary'].max()]
# Out:
#     Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 8  Chemical Engineering                 63200.0                  107000.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary Group
# 8                            71900.0                           194000.0  STEM

# %%
df['Mid-Career 90th Percentile Salary']-df['Mid-Career 10th Percentile Salary']
# Out:
# 0     109800.0
# 1      96700.0
# 2     113700.0
# 3     104200.0
# 4      85400.0
# 5      96200.0
# 6      98100.0
# 7     108200.0
# 8     122100.0
# 9     102700.0
# 10     84600.0
# 11    105500.0
# 12     95900.0
# 13     98000.0
# 14    114700.0
# 15     74800.0
# 16    116300.0
# 17    159400.0
# 18     72700.0
# 19     98700.0
# 20     99600.0
# 21    102100.0
# 22    147800.0
# 23     70000.0
# 24     92000.0
# 25    111000.0
# 26     76000.0
# 27     66400.0
# 28    112000.0
# 29     88500.0
# 30    115900.0
# 31     84500.0
# 32     71300.0
# 33    118800.0
# 34    106600.0
# 35    100700.0
# 36    132900.0
# 37    137800.0
# 38     99300.0
# 39    107300.0
# 40     50700.0
# 41     65300.0
# 42    132500.0
# 43     57600.0
# 44    122000.0
# 45    126800.0
# 46     95400.0
# 47     66700.0
# 48     87300.0
# 49     65400.0
# dtype: float64

# %%
df['Spread']=df['Mid-Career 90th Percentile Salary']-df['Mid-Career 10th Percentile Salary']

# %%
df.head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 0             Accounting                 46000.0                   77100.0
# 1  Aerospace Engineering                 57700.0                  101000.0
# 2            Agriculture                 42600.0                   71900.0
# 3           Anthropology                 36800.0                   61500.0
# 4           Architecture                 41600.0                   76800.0
#
#    Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 0                            42200.0                           152000.0
# 1                            64300.0                           161000.0
# 2                            36300.0                           150000.0
# 3                            33800.0                           138000.0
# 4                            50600.0                           136000.0
#
#       Group    Spread
# 0  Business  109800.0
# 1      STEM   96700.0
# ...

# %%
df['Spread'].min()
# Out:
# np.float64(50700.0)

# %%
df[df['Spread']==df['Spread'].min()]
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 40             Nursing                 54200.0                   67000.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 40                            47600.0                            98300.0
#
#        Group   Spread
# 40  Business  50700.0

# %%
df['Spread'].sort_values()
# Out:
# 40     50700.0
# 43     57600.0
# 41     65300.0
# 49     65400.0
# 27     66400.0
# 47     66700.0
# 23     70000.0
# 32     71300.0
# 18     72700.0
# 15     74800.0
# 26     76000.0
# 31     84500.0
# 10     84600.0
# 4      85400.0
# 48     87300.0
# 29     88500.0
# 24     92000.0
# 46     95400.0
# 12     95900.0
# 5      96200.0
# 1      96700.0
# 13     98000.0
# 6      98100.0
# 19     98700.0
# 38     99300.0
# 20     99600.0
# 35    100700.0
# 21    102100.0
# 9     102700.0
# 3     104200.0
# 11    105500.0
# 34    106600.0
# 39    107300.0
# 7     108200.0
# 0     109800.0
# 25    111000.0
# 28    112000.0
# 2     113700.0
# 14    114700.0
# 30    115900.0
# 16    116300.0
# 33    118800.0
# 44    122000.0
# 8     122100.0
# 45    126800.0
# 42    132500.0
# 36    132900.0
# 37    137800.0
# 22    147800.0
# 17    159400.0
# Name: Spread, dtype: float64

# %%
df['Spread'].sort_values(ascending=False).head(5)
# Out:
# 17    159400.0
# 22    147800.0
# 37    137800.0
# 36    132900.0
# 42    132500.0
# Name: Spread, dtype: float64

# %%
df.sort_values(by='Mid-Career 90th Percentile Salary',ascending=False).head()
# Out:
#      Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17             Economics                 50100.0                   98600.0
# 22               Finance                 47900.0                   88300.0
# 8   Chemical Engineering                 63200.0                  107000.0
# 37                  Math                 45400.0                   92400.0
# 44               Physics                 50300.0                   97300.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 8                             71900.0                           194000.0
# 37                            45200.0                           183000.0
# 44                            56000.0                           178000.0
#
#        Group    Spread
# 17  Business  159400.0
# 22  Business  147800.0
# ...

# %% [markdown]
# ### Finding majors with the highest potential

# %%
df.sort_values(by="Spread",ascending=False).head()
# Out:
#    Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 17           Economics                 50100.0                   98600.0
# 22             Finance                 47900.0                   88300.0
# 37                Math                 45400.0                   92400.0
# 36           Marketing                 40800.0                   79600.0
# 42          Philosophy                 39900.0                   81200.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 17                            50600.0                           210000.0
# 22                            47200.0                           195000.0
# 37                            45200.0                           183000.0
# 36                            42100.0                           175000.0
# 42                            35500.0                           168000.0
#
#        Group    Spread
# 17  Business  159400.0
# 22  Business  147800.0
# ...

# %%
df.sort_values(by="Spread",ascending=False).head()[['Undergraduate Major','Spread']]
# Out:
#    Undergraduate Major    Spread
# 17           Economics  159400.0
# 22             Finance  147800.0
# 37                Math  137800.0
# 36           Marketing  132900.0
# 42          Philosophy  132500.0

# %%
df.sort_values(by='Mid-Career Median Salary',ascending=False).head()
# Out:
#        Undergraduate Major  Starting Median Salary  Mid-Career Median Salary  \
# 8     Chemical Engineering                 63200.0                  107000.0
# 12    Computer Engineering                 61400.0                  105000.0
# 19  Electrical Engineering                 60900.0                  103000.0
# 1    Aerospace Engineering                 57700.0                  101000.0
# 17               Economics                 50100.0                   98600.0
#
#     Mid-Career 10th Percentile Salary  Mid-Career 90th Percentile Salary  \
# 8                             71900.0                           194000.0
# 12                            66100.0                           162000.0
# 19                            69300.0                           168000.0
# 1                             64300.0                           161000.0
# 17                            50600.0                           210000.0
#
#        Group    Spread
# 8       STEM  122100.0
# ...

# %%
df.sort_values(by='Mid-Career Median Salary',ascending=False).head()[['Undergraduate Major','Mid-Career Median Salary']]
# Out:
#        Undergraduate Major  Mid-Career Median Salary
# 8     Chemical Engineering                  107000.0
# 12    Computer Engineering                  105000.0
# 19  Electrical Engineering                  103000.0
# 1    Aerospace Engineering                  101000.0
# 17               Economics                   98600.0

# %%
df.groupby('Group').count()
# Out:
#           Undergraduate Major  Starting Median Salary  \
# Group
# Business                   12                      12
# HASS                       22                      22
# STEM                       16                      16
#
#           Mid-Career Median Salary  Mid-Career 10th Percentile Salary  \
# Group
# Business                        12                                 12
# HASS                            22                                 22
# STEM                            16                                 16
#
#           Mid-Career 90th Percentile Salary  Spread
# Group
# Business                                 12      12
# HASS                                     22      22
# STEM                                     16      16

# %%
df.groupby('Group').mean(numeric_only=True)
# Out:
#           Starting Median Salary  Mid-Career Median Salary  \
# Group
# Business            44633.333333              75083.333333
# HASS                37186.363636              62968.181818
# STEM                53862.500000              90812.500000
#
#           Mid-Career 10th Percentile Salary  \
# Group
# Business                       43566.666667
# HASS                           34145.454545
# STEM                           56025.000000
#
#           Mid-Career 90th Percentile Salary         Spread
# Group
# Business                      147525.000000  103958.333333
# HASS                          129363.636364   95218.181818
# STEM                          157625.000000  101600.000000
